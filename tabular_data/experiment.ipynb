# %%
import sys
import os
sys.path.append(os.path.abspath('./datasets'))

import data

# %%
x_train_mnist, x_test_mnist, y_train_mnist, y_test_mnist = data.get_data('downscaled_mnist_pca', 2)

# %%
x_train_hm, x_test_hm, y_train_hm, y_test_hm = data.get_data('hidden_manifold', 2, 6)

# %%
x_train_tc, x_test_tc, y_train_tc, y_test_tc = data.get_data('two_curves', 2, 5)

# %%
print(x_train_mnist.shape)
print(x_train_hm.shape)
print(x_train_tc.shape)
# Out:
# (11552, 2)
# (240, 2)
# (240, 2)

# %%
print(x_train_hm[1])
print(x_train_tc[1])
# Out:
# [0.35377397 0.09623156]
# [0.08839754 0.177076  ]
